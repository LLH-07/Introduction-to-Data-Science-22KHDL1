# %% [markdown]
# # **INTRODUCE TO DATA SCIENCE - FINAL PROJECT**

# %% [markdown]
# ## Group 5

# %% [markdown]
# #### **Members information**

# %% [markdown]
# |    ID    |          Name         |
# |----------|-----------------------|
# |22127117  | Lý Liên Hoa           |
# |22127232  | Lê Thị Ngọc Linh      |
# |22127069  | Nguyễn Đặng Hoàng Dinh|
# |22127139  | Hoàng Duy Hưng        |

# %% [markdown]
# ## **1. Collecting Data**

# %% [markdown]
# ### **1.1. About data is about to be crawled**

# %% [markdown]
# ### **1.2. About permission**

# %% [markdown]
# ### **1.3. Crawling data**

# %% [markdown]
# Thực hiện viết về các bước thực hiện ở bước này

# %% [markdown]
# ##### **a. Import necessary libraries**

# %% [markdown]
# ...

# %% [markdown]
# ##### **d. Save to csv file**

# %% [markdown]
# ## **2. Exploratory Data Analysis (EDA) & Preprocessing**

# %% [markdown]
# **Import libraries**

# %%
import requests
import numpy as np
import pandas as pd

# %% [markdown]
# **Read data**

# %%
data_origin = pd.read_csv("data_origin.csv")
print (data_origin)
# Out:
#                                            Product Name  \
# 0     Gel chấm mụn, mờ thâm Decumar Advance THC 20g ...
# 1     Dung dịch vệ sinh vùng kín Bimunica 250ml dành...
# 2     Kem giảm thâm vùng nách, mông, bikini Neothera...
# 3     Gel rửa mặt SVR Sebiaclear Gel Moussant 200ml ...
# 4     Bọt vệ sinh nam giới Sumely Men's Sanitary Foa...
# ...                                                 ...
# 1994  Viên uống Tiền Đình Khang KGA dùng cho rối loạ...
# 1995  Viên nang mềm Xương Khớp PV Forte hỗ trợ khớp,...
# 1996  Gói cốm Futizon PV Pharma hỗ trợ bù nước, điện...
# 1997  Sữa Pregestimil Lipil Mead Johnson bổ sung din...
# 1998  Viên sủi Haas Vital Pezsgés Multi-vitamin hươn...
#
#                       Category        Dosage Form     Price     Trademark  \
# 0              Chăm sóc cơ thể                Gel  105000.0       DECUMAR
# 1              Chăm sóc cơ thể                NaN  230000.0           NaN
# ...

# %% [markdown]
# ### **2.1. How many rows and columns?**

# %% [markdown]
# Crawled data included: 1999 rows and 8 columns

# %% [markdown]
# ### **2.2. Row detail**

# %% [markdown]
# ##### **a. Meaning of each row**

# %% [markdown]
# 1. Product name:
# 2. Category:
# 3. Dosage form:
# 4. Price
# 5. Trademark
# 6. Brand origin
# 7. Country
# 8. Rating

# %% [markdown]
# ##### **b. Are there duplicated rows**?

# %% [markdown]
# nếu có, thì xử lý  nó như nào? xử lý nó ở đây luôn

# %% [markdown]
# ### **2.3. Column detail**

# %% [markdown]
# ##### **a. Meaning of each column**

# %% [markdown]
# ##### **b. What is the current data type of each column? Are there columns having inappropriate data types?**

# %% [markdown]
# Nếu không phù hợp --> reformat --> kết quả sau khi reformat

# %% [markdown]
# - Ở đây có thể nói sao, để gộp thành Châu lục, với General function
# - show bảng mới, dtypes ra

# %% [markdown]
# ### **2.4. Value distribution**

# %% [markdown]
# ##### **a. With each numerical column, how are the values distributed?**

# %% [markdown]
# **Description**

# %% [markdown]
# In this part, for each numerical column, we will calculate:
# - `missing_ratio`: Percentage (from 0 to 100) of missing values
# - `min`: The min
# - `lower_quartile`: The lower quartile (phân vị 25)
# - `median`: The median (phân vị 50)
# - `upper_quartile`: The upper quartile (phân vị 75)
# - `max`: The max

# %% [markdown]
# **Calculation**

# %% [markdown]
# - Rút ra nhận xét, ví dụ min, max, có tồn tại giá trị outlier không, có nhiều không,...
# - Nếu có missing value, null values, thì xử lý như nào? Mô tả...
# - Vẽ biểu đồ tần suất xuất hiện.

# %% [markdown]
# ##### **b. With each category column, how are the values distributed?**

# %% [markdown]
# **Description**

# %% [markdown]
# In this part, for each category column, we will calculate:
# - `missing_ratio`: Percentage (from 0 to 100) of missing values
# - `num_values`: Number of different values (excluding missing values): With columns whose type is categorical, it is a set with a finite number of categories.
# - `value_ratios`: The percentage (from 0 to 100) of each value (excluding missing values) is sorted by decreasing percentage.

# %% [markdown]
# **Calculation**

# %% [markdown]
# - Nếu có missing value, null values, thì xử lý như nào? Mô tả...
# - Vẽ biểu đồ tần suất xuất hiện
# - Nhận xét tỷ lệ xuất hiện

# %% [markdown]
# <span style="color:red"> **Lưu dataframe sau khi xử lý thành file mới và (có thể) lưu vào vào biến mới có tên, "processed_df" , để cho các bước sau chỉ sử dụng, tên processed_df chung cho việc đặt các câu hỏi** </span>

# %% [markdown]
# ## **3. Asking Meaning Questions**

# %% [markdown]
# **Question 1**:
#
# **Question 2**:
#
# **Question 3**:
#
# **Question 4**:
#
# **Question 5**:

# %% [markdown]
# ## **4. Pre-processing & Analyzing Data to Answer each Questions**

# %% [markdown]
# ## **5. Building models**

# %% [markdown]
# ## **6. Reflection**
