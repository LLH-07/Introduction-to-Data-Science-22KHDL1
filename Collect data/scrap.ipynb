# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
URL = "https://nhathuoclongchau.com.vn/thuc-pham-chuc-nang"

# %%
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept': '*/*',
    'Connection': 'keep-alive'
}

# %%
# HTTP Request
webpage =  requests.get(URL,headers=HEADERS)

# %%
type(webpage.content)
# Out:
# bytes

# %%
#Soup object containing all data
soup = BeautifulSoup(webpage.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
# Find all links with specified class
links = soup.find_all("a", attrs={'class': 'block px-3'})

# %%
links
# Out:
# [<a class="block px-3" href="/thuc-pham-chuc-nang/vien-uong-ho-tro-tien-liet-tuyen-bo-than-golex-the-oxford-30-v.html"><div class="mb-1 flex min-h-[36px] items-end md:mt-0 md:min-h-[20px]"></div><h3 class="overflow-hidden text-gray-10 text-body2 font-semibold line-clamp-2 md:line-clamp-3 mb-1 md:mb-2">Viên uống Golex Ocavill hỗ trợ chống lại sự phình to của tuyến tiền liệt, cải thiện các rối loạn tiểu tiện (30 viên)</h3></a>,
#  <a class="block px-3" href="/thuc-pham-chuc-nang/siro-giup-giam-ho-bo-phe-labebe-120-ml.html"><div class="mb-1 flex min-h-[36px] items-end md:mt-0 md:min-h-[20px]"></div><h3 class="overflow-hidden text-gray-10 text-body2 font-semibold line-clamp-2 md:line-clamp-3 mb-1 md:mb-2">Siro Bổ Phế Lábebé 120ml hỗ trợ bổ phế, giảm ho, giảm đờm, giảm đau họng</h3></a>,
# ...

# %%
link = links[0].get('href')

# %%
product_list = "https://nhathuoclongchau.com.vn/" + link

# %%
product_list
# Out:
# 'https://nhathuoclongchau.com.vn//thuc-pham-chuc-nang/vien-uong-ho-tro-tien-liet-tuyen-bo-than-golex-the-oxford-30-v.html'

# %%
new_webpage =  requests.get(product_list,headers=HEADERS)

# %%
new_webpage
# Out:
# <Response [200]>

# %%
new_soup = BeautifulSoup(new_webpage.content, "html.parser")

# %%
new_soup
# Out:
# <!DOCTYPE html>
# ...

# %%
a = new_soup.find("h1", attrs={"data-test":'product_name'})
b = a.text

# %%
b= b.removesuffix("n")
print(b)
# Out:
# Hộp 30 Viê

# %%
elements = new_soup.find("div", attrs ={"class":"css-1e2qim1 text-gray-10"}).text

# %%
elements
# Out:
# 'Viên nén'

# %%
def get_specific_info(soup):
    try:
        elements = new_soup.find_all("div", attrs ={"class":"css-1e2qim1 text-gray-10"})
        
        if len(elements) > 0:
            specification = elements[0].text  # Quy cách
            brand_origin = elements[1].text   # Xuất xứ thương hiệu
            country = elements[3].text #xuẩt xứ thương hiệu 
        else:
            specification = brand_origin = "NULL"
        
        return brand_origin
    
    except Exception as e:
        print(f"An error occurred: {e}")
        return None
b = get_specific_info(soup)
print(b)
# Out:
# Hộp 30 Viên
